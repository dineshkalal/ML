# %% [markdown]
# SeaBorn Data Visualization

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
datasets= sns.get_dataset_names()

# %%
datasets
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Display first few rows
print(iris.tail())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
#Pairplot (Scatter matrix)

#This helps visualize relationships between numerical features.

sns.pairplot(iris, hue="species", markers=["o", "s", "D"])
plt.show()

# %%
#Bxplot

#Boxplots are useful for visualizing distributions and detecting outliers.

plt.figure(figsize=(8, 6))
sns.boxplot(x="species", y="sepal_length", data=iris)
plt.show()

# %%
#Violin Plot

#A combination of boxplot and KDE plot to show distribution.

plt.figure(figsize=(8, 6))
sns.violinplot(x="species", y="petal_length", data=iris)
plt.show()

# %%
#Swarm Plot

#Shows individual data points along with the distribution.

plt.figure(figsize=(8, 6))
sns.swarmplot(x="species", y="sepal_width", data=iris)
plt.show()

# %%
#Heatmap (Correlation Matrix)

#Shows the correlation between different numerical features.
plt.figure(figsize=(8, 6))
sns.heatmap(iris.corr(),annot=True,cmap="coolwarm",linewidths=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-87dcf970a15a> in <cell line: 0>()
#       3 #Shows the correlation between different numerical features.
#       4 plt.figure(figsize=(8, 6))
# ----> 5 sns.heatmap(iris.corr(),annot=True,cmap="coolwarm",linewidths=0.5)
#       6 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# ...

# %%
#KDE Plot (Density Plot)

#Visualizes the density distribution of a feature.

plt.figure(figsize=(8, 6))
sns.kdeplot(data=iris, x="petal_length", hue="species", fill=True)
plt.show()

# %%
#Histogram

plt.figure(figsize=(8, 6))
sns.histplot(iris, x="sepal_length", hue="species", kde=False, bins=10)
plt.show()

# %%
 #Create a sample dataset
data = {
    "Student": ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"],
    "Maths": [78, 85, 67, 90, 76, 92, 88, 79, 84, 91],
    "Science": [80, 89, 70, 95, 74, 97, 85, 81, 86, 93],
    "English": [72, 83, 65, 88, 71, 90, 80, 75, 78, 85],
    "Attendance": [90, 95, 85, 98, 88, 99, 92, 89, 94, 97]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   Student  Maths  Science  English  Attendance
# 0       A     78       80       72          90
# 1       B     85       89       83          95
# 2       C     67       70       65          85
# 3       D     90       95       88          98
# 4       E     76       74       71          88
# 5       F     92       97       90          99
# 6       G     88       85       80          92
# 7       H     79       81       75          89
# 8       I     84       86       78          94
# 9       J     91       93       85          97

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(x="Student", y="Maths", data=df, marker="o", label="Maths")
# Out:
# <Axes: xlabel='Student', ylabel='Maths'>
