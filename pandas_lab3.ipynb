# %%
import pandas as pd
import numpy as np

# %%
energy=pd.read_csv('Energy.csv')

# %%
energy
# Out:
#       iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0          AFG  Afghanistan  1900                   NaN                   NaN
# 1          AFG  Afghanistan  1901                   NaN                 0.000
# 2          AFG  Afghanistan  1902                   NaN                 0.000
# 3          AFG  Afghanistan  1903                   NaN                 0.000
# 4          AFG  Afghanistan  1904                   NaN                 0.000
# ...        ...          ...   ...                   ...                   ...
# 17427      ZWE     Zimbabwe  2015               -25.013               -10.847
# 17428      ZWE     Zimbabwe  2016               -37.694               -12.257
# 17429      ZWE     Zimbabwe  2017                 8.375                 1.697
# 17430      ZWE     Zimbabwe  2018                22.555                 4.952
# 17431      ZWE     Zimbabwe  2019               -35.015                -9.422
#
# ...

# %%
for col in energy.columns:
    print(col)
# Out:
# iso_code
# country
# year
# coal_prod_change_pct
# coal_prod_change_twh
# gas_prod_change_pct
# gas_prod_change_twh
# oil_prod_change_pct
# oil_prod_change_twh
# energy_cons_change_pct
# energy_cons_change_twh
# biofuel_share_elec
# biofuel_elec_per_capita
# biofuel_cons_change_pct
# biofuel_share_energy
# biofuel_cons_change_twh
# biofuel_consumption
# biofuel_cons_per_capita
# carbon_intensity_elec
# coal_share_elec
# coal_cons_change_pct
# coal_share_energy
# coal_cons_change_twh
# coal_consumption
# coal_elec_per_capita
# coal_cons_per_capita
# coal_production
# coal_prod_per_capita
# electricity_generation
# biofuel_electricity
# coal_electricity
# fossil_electricity
# gas_electricity
# hydro_electricity
# nuclear_electricity
# oil_electricity
# other_renewable_electricity
# other_renewable_exc_biofuel_electricity
# renewables_electricity
# solar_electricity
# wind_electricity
# energy_per_gdp
# energy_per_capita
# fossil_cons_change_pct
# fossil_share_energy
# ...

# %%
#our focus countries
focus_countries = ['United States', 'India', 'Russia', 'United Kingdom', 'China']

# %%
#filter for focus countries
power_data = energy[energy["country"].isin(focus_countries)]
power_data
# Out:
#       iso_code        country  year  coal_prod_change_pct  \
# 3345       CHN          China  1900                   NaN
# 3346       CHN          China  1901                   NaN
# 3347       CHN          China  1902                   NaN
# 3348       CHN          China  1903              1972.001
# 3349       CHN          China  1904                 6.467
# ...        ...            ...   ...                   ...
# 16365      USA  United States  2016               -18.271
# 16366      USA  United States  2017                 6.534
# 16367      USA  United States  2018                -1.676
# 16368      USA  United States  2019                -7.130
# 16369      USA  United States  2020                   NaN
#
#        coal_prod_change_twh  gas_prod_change_pct  gas_prod_change_twh  \
# 3345                    NaN                  NaN                  NaN
# 3346                  0.000                  NaN                0.000
# ...

# %%
power_data = power_data[power_data["year"] >= 2000] #return data for only years greater than or equal to 2000
power_data
# Out:
#       iso_code        country  year  coal_prod_change_pct  \
# 3445       CHN          China  2000                 3.713
# 3446       CHN          China  2001                 5.946
# 3447       CHN          China  2002                 6.794
# 3448       CHN          China  2003                18.125
# 3449       CHN          China  2004                17.095
# ...        ...            ...   ...                   ...
# 16365      USA  United States  2016               -18.271
# 16366      USA  United States  2017                 6.534
# 16367      USA  United States  2018                -1.676
# 16368      USA  United States  2019                -7.130
# 16369      USA  United States  2020                   NaN
#
#        coal_prod_change_twh  gas_prod_change_pct  gas_prod_change_twh  \
# 3445                294.468                7.945               20.177
# 3446                489.119               11.504               31.536
# ...

# %%
#get column names with the word consumption in them
consumption_cols = [col for col in power_data.keys()[power_data.keys().str.contains('consumption')]]

# %%
consumption_cols
# Out:
# ['biofuel_consumption',
#  'coal_consumption',
#  'fossil_fuel_consumption',
#  'gas_consumption',
#  'hydro_consumption',
#  'low_carbon_consumption',
#  'nuclear_consumption',
#  'oil_consumption',
#  'other_renewable_consumption',
#  'primary_energy_consumption',
#  'renewables_consumption',
#  'solar_consumption',
#  'wind_consumption']

# %%
power_data.keys().str.contains('consumption')
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False,  True, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#         True, False, False, False, False, False,  True, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False,  True, False, False])

# %%
consumption_cols.append('country') #append country column
consumption_cols.append('year') #append year column
consumption_cols
# Out:
# ['biofuel_consumption',
#  'coal_consumption',
#  'fossil_fuel_consumption',
#  'gas_consumption',
#  'hydro_consumption',
#  'low_carbon_consumption',
#  'nuclear_consumption',
#  'oil_consumption',
#  'other_renewable_consumption',
#  'primary_energy_consumption',
#  'renewables_consumption',
#  'solar_consumption',
#  'wind_consumption',
#  'country',
#  'year']

# %%
power_data = power_data[consumption_cols]
power_data
# Out:
#        biofuel_consumption  coal_consumption  fossil_fuel_consumption  \
# 3445                 0.000          8211.413                11119.510
# 3446                 0.053          8635.762                11633.089
# 3447                 0.444          9467.465                12699.612
# 3448                 1.618         11283.068                14896.342
# 3449                 5.556         13155.290                17375.205
# ...                    ...               ...                      ...
# 16365              411.458          3960.744                21428.950
# 16366              411.034          3852.596                21331.723
# 16367              406.412          3689.462                22196.473
# 16368              406.191          3150.181                21891.102
# 16369                  NaN               NaN                      NaN
#
#        gas_consumption  hydro_consumption  low_carbon_consumption  \
# ...

# %%
#group by country and sum the values in the remainig columns
total_power_consumed = power_data.groupby(['country']).sum()

# %%
total_power_consumed
# Out:
#                 biofuel_consumption  coal_consumption  \
# country
# China                       337.917        361469.117
# India                        13.867         68108.280
# Russia                        0.000         22036.068
# United Kingdom              158.721          6900.709
# United States              4934.899        106729.026
#
#                 fossil_fuel_consumption  gas_consumption  hydro_consumption  \
# country
# China                        487737.471        24939.645          36363.133
# India                        115070.532         8771.234           5895.692
# Russia                       137378.463        82622.290           9059.757
# United Kingdom                42985.801        17746.279            264.667
# United States                447216.452       134314.844          13941.447
#
#                 low_carbon_consumption  nuclear_consumption  oil_consumption  \
# country
# ...

# %%
total_power_consumed.to_csv('Myenergy.csv') #save as csv
